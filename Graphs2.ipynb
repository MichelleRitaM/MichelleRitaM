# %% [markdown]
# <a href="https://colab.research.google.com/github/MichelleRitaM/MichelleRitaM/blob/main/Graphs2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas Package
import pandas as pd
data = pd.read_csv("https://modcom.co.ke/datasets/bank.csv")
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# **Obejctive**
# 1. ML - To Create a model to assist in predicting Loan Default for a new member.
# 2. Which attributes contribute much to the target varriables.
# 3. General Analytics
#     -Gender propotion.
#     -Which gender took more loans on average.
#     -Was there positive correlation between applicant amount and loan Loan amount.
#     -Which property area was most used.

# %%
#gender proportion
data.groupby(['Gender']).size()
# Out:
# Gender
# Female    112
# Male      489
# dtype: int64

# %%
#check empties
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
# fill missing
data['Gender'].fillna('Unknown', inplace= True)
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# fill missing
data['Gender'].fillna('Unknown', inplace= True)
data.isnull().sum()
data.groupby(['Gender']).size()
# Out:
# Gender
# Female     112
# Male       489
# Unknown     13
# dtype: int64

# %%
#fill missing
data['Gender'].fillna('Unknown', inplace= True)
data['Dependents'].replace({'3+:3'}, inplace= True) #replace 3+ with 3
data['Dependents'].fillna('99', inplace= True) # 99 represents empty
data['Self_Employed'].fillna('Unknown', inplace= True) # 99 represents empty

#Loan Amount
loan_median = data['LoanAmount'].median()
data['LoanAmount'].fillna(loan_median,inplace= True)

term_median = data['Loan_Amount_Term'].median()
data['Loan_Amount_Term'].fillna(term_median, inplace= True)
data['Credit_History'].fillna('99',inplace= True) #99 represent empty

#Drop the remaining empties
data.dropna(inplace= True)

data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.isnull().sum()
data.tail(50)
# Out:
#       Loan_ID   Gender Married Dependents     Education Self_Employed  \
# 564  LP002832     Male     Yes          2      Graduate            No
# 565  LP002833     Male     Yes          0  Not Graduate            No
# 566  LP002836     Male      No          0      Graduate            No
# 567  LP002837     Male     Yes         3+      Graduate            No
# 568  LP002840   Female      No          0      Graduate            No
# 569  LP002841     Male     Yes          0      Graduate            No
# 570  LP002842     Male     Yes          1      Graduate            No
# 571  LP002847     Male     Yes         99      Graduate            No
# 572  LP002855     Male     Yes          2      Graduate            No
# 573  LP002862     Male     Yes          2  Not Graduate            No
# 574  LP002863     Male     Yes         3+      Graduate            No
# 575  LP002868     Male     Yes          2      Graduate            No
# 576  LP002872  Unknown     Yes          0      Graduate            No
# 577  LP002874     Male      No          0      Graduate            No
# 578  LP002877     Male     Yes          1      Graduate            No
# 579  LP002888     Male      No          0      Graduate       Unknown
# 580  LP002892     Male     Yes          2      Graduate            No
# 581  LP002893     Male      No          0      Graduate            No
# 582  LP002894   Female     Yes          0      Graduate            No
# 583  LP002898     Male     Yes          1      Graduate            No
# 584  LP002911     Male     Yes          1      Graduate            No
# 585  LP002912     Male     Yes          1      Graduate            No
# 586  LP002916     Male     Yes          0      Graduate            No
# 587  LP002917   Female      No          0  Not Graduate            No
# 588  LP002925  Unknown      No          0      Graduate            No
# 589  LP002926     Male     Yes          2      Graduate           Yes
# 590  LP002928     Male     Yes          0      Graduate            No
# 591  LP002931     Male     Yes          2      Graduate           Yes
# 592  LP002933  Unknown      No         3+      Graduate           Yes
# 593  LP002936     Male     Yes          0      Graduate            No
# 594  LP002938     Male     Yes          0      Graduate           Yes
# 595  LP002940     Male      No          0  Not Graduate            No
# 596  LP002941     Male     Yes          2  Not Graduate           Yes
# 597  LP002943     Male      No         99      Graduate            No
# 598  LP002945     Male     Yes          0      Graduate           Yes
# 599  LP002948     Male     Yes          2      Graduate            No
# 600  LP002949   Female      No         3+      Graduate       Unknown
# 601  LP002950     Male     Yes          0  Not Graduate       Unknown
# 602  LP002953     Male     Yes         3+      Graduate            No
# 603  LP002958     Male      No          0      Graduate            No
# 604  LP002959   Female     Yes          1      Graduate            No
# 605  LP002960     Male     Yes          0  Not Graduate            No
# 606  LP002961     Male     Yes          1      Graduate            No
# 607  LP002964     Male     Yes          2  Not Graduate            No
# 608  LP002974     Male     Yes          0      Graduate            No
# 609  LP002978   Female      No          0      Graduate            No
# 610  LP002979     Male     Yes         3+      Graduate            No
# 611  LP002983     Male     Yes          1      Graduate            No
# 612  LP002984     Male     Yes          2      Graduate            No
# 613  LP002990   Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 564             8799                0.0       258.0             360.0
# 565             4467                0.0       120.0             360.0
# 566             3333                0.0        70.0             360.0
# 567             3400             2500.0       123.0             360.0
# 568             2378                0.0         9.0             360.0
# 569             3166             2064.0       104.0             360.0
# 570             3417             1750.0       186.0             360.0
# 571             5116             1451.0       165.0             360.0
# 572            16666                0.0       275.0             360.0
# 573             6125             1625.0       187.0             480.0
# 574             6406                0.0       150.0             360.0
# 575             3159              461.0       108.0              84.0
# 576             3087             2210.0       136.0             360.0
# 577             3229             2739.0       110.0             360.0
# 578             1782             2232.0       107.0             360.0
# 579             3182             2917.0       161.0             360.0
# 580             6540                0.0       205.0             360.0
# 581             1836            33837.0        90.0             360.0
# 582             3166                0.0        36.0             360.0
# 583             1880                0.0        61.0             360.0
# 584             2787             1917.0       146.0             360.0
# 585             4283             3000.0       172.0              84.0
# 586             2297             1522.0       104.0             360.0
# 587             2165                0.0        70.0             360.0
# 588             4750                0.0        94.0             360.0
# 589             2726                0.0       106.0             360.0
# 590             3000             3416.0        56.0             180.0
# 591             6000                0.0       205.0             240.0
# 592             9357                0.0       292.0             360.0
# 593             3859             3300.0       142.0             180.0
# 594            16120                0.0       260.0             360.0
# 595             3833                0.0       110.0             360.0
# 596             6383             1000.0       187.0             360.0
# 597             2987                0.0        88.0             360.0
# 598             9963                0.0       180.0             360.0
# 599             5780                0.0       192.0             360.0
# 600              416            41667.0       350.0             180.0
# 601             2894             2792.0       155.0             360.0
# 602             5703                0.0       128.0             360.0
# 603             3676             4301.0       172.0             360.0
# 604            12000                0.0       496.0             360.0
# 605             2400             3800.0       128.0             180.0
# 606             3400             2500.0       173.0             360.0
# 607             3987             1411.0       157.0             360.0
# 608             3232             1950.0       108.0             360.0
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#     Credit_History Property_Area Loan_Status
# 564            0.0         Urban           N
# 565             99         Rural           Y
# 566            1.0         Urban           Y
# 567            0.0         Rural           N
# 568            1.0         Urban           N
# 569            0.0         Urban           N
# 570            1.0         Urban           Y
# 571            0.0         Urban           N
# 572            1.0         Urban           Y
# 573            1.0     Semiurban           N
# 574            1.0     Semiurban           N
# 575            1.0         Urban           Y
# 576            0.0     Semiurban           N
# 577            1.0         Urban           Y
# 578            1.0         Rural           Y
# 579            1.0         Urban           Y
# 580            1.0     Semiurban           Y
# 581            1.0         Urban           N
# 582            1.0     Semiurban           Y
# 583             99         Rural           N
# 584            0.0         Rural           N
# 585            1.0         Rural           N
# 586            1.0         Urban           Y
# 587            1.0     Semiurban           Y
# 588            1.0     Semiurban           Y
# 589            0.0     Semiurban           N
# 590            1.0     Semiurban           Y
# 591            1.0     Semiurban           N
# 592            1.0     Semiurban           Y
# 593            1.0         Rural           Y
# 594            1.0         Urban           Y
# 595            1.0         Rural           Y
# 596            1.0         Rural           N
# 597            0.0     Semiurban           N
# 598            1.0         Rural           Y
# 599            1.0         Urban           Y
# 600             99         Urban           N
# 601            1.0         Rural           Y
# 602            1.0         Urban           Y
# 603            1.0         Rural           Y
# 604            1.0     Semiurban           Y
# 605            1.0         Urban           N
# 606            1.0     Semiurban           Y
# 607            1.0         Rural           Y
# 608            1.0         Rural           Y
# 609            1.0         Rural           Y
# 610            1.0         Rural           Y
# 611            1.0         Urban           Y
# 612            1.0         Urban           Y
# 613            0.0     Semiurban           N

# %%
data.groupby(['Gender']).size()
# Out:
# Gender
# Female     111
# Male       487
# Unknown     13
# dtype: int64

# %%
data.groupby(['Gender','Dependents','LoanAmount']).size()
# Out:
# Gender   Dependents  LoanAmount
# Female   0           9.0           1
#                      30.0          1
#                      36.0          1
#                      44.0          1
#                      46.0          1
#                                   ..
# Unknown  2           112.0         1
#                      132.0         1
#          3+          292.0         1
#                      370.0         1
#                      700.0         1
# Length: 404, dtype: int64

# %%
data.groupby(['Gender','Dependents'])['LoanAmount','Self_Employed'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     LoanAmount
# Gender  Dependents
# Female  0           113.512500
#         1           166.315789
#         2           119.000000
#         3+          244.333333
#         99          129.500000
# Male    0           142.596899
#         1           155.060976
#         2           152.489130
#         3+          167.000000
#         99          122.000000
# Unknown 0           131.857143
#         1           182.000000
#         2           122.000000
#         3+          454.000000

# %%
data.groupby(['Gender','Credit_History'])['LoanAmount','Dependents'].std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                         LoanAmount
# Gender  Credit_History
# Female  0.0              49.574513
#         1.0              84.427527
#         99               73.972968
# Male    0.0              90.714393
#         1.0              75.399481
#         99              115.179126
# Unknown 0.0              12.858201
#         1.0             195.336746
#         99                     NaN

# %%
data.groupby(['Gender','Credit_History'])['LoanAmount','Dependents'].corr()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                    LoanAmount
# Gender  Credit_History
# Female  0.0            LoanAmount         1.0
#         1.0            LoanAmount         1.0
#         99             LoanAmount         1.0
# Male    0.0            LoanAmount         1.0
#         1.0            LoanAmount         1.0
#         99             LoanAmount         1.0
# Unknown 0.0            LoanAmount         1.0
#         1.0            LoanAmount         1.0
#         99             LoanAmount         NaN

# %%
#Graphs with seaborn
import seaborn as sns
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('ggplot')
sns.stripplot(x = 'Gender', y= 'LoanAmount', hue = 'Credit_History', data= data)
plt.title("Gender vs Loan Amount in USD")
#there are graphs that only work with continuous variables
# Out:
# Text(0.5, 1.0, 'Gender vs Loan Amount in USD')

# %%
#palette = flare, creast, rocket, magma, virids, Blues_d
plt.style.use('ggplot')
sns.stripplot(x = 'Gender', y= 'LoanAmount', hue = 'Dependents', palette= "crest", data= data)
plt.title("Gender vs Loan Amount in USD")
#there are graphs that only work with continuous variables
# Out:
# Text(0.5, 1.0, 'Gender vs Loan Amount in USD')

# %%
#swarmplot
plt.style.use('seaborn')
sns.swarmplot(x = 'Gender', y= 'LoanAmount', hue = 'Dependents', palette= "rocket", data= data)
plt.title("Gender vs Loan Amount in USD")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 32.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Gender vs Loan Amount in USD')

# %%
plt.style.use('fast')
sns.violinplot(x = 'Gender', y= 'LoanAmount', hue = 'Dependents', palette= "rocket", data= data)
plt.title("Gender vs Loan Amount in USD")
# Out:
# Text(0.5, 1.0, 'Gender vs Loan Amount in USD')

# %%
#lm plot
plt.style.use('seaborn')
sns.lmplot(x = 'ApplicantIncome', y= 'LoanAmount', hue = 'Dependents', palette= "magma", data= data)
plt.title("ApplicantIncoem vs Loan Amount in USD")
# Out:
# Text(0.5, 1.0, 'ApplicantIncoem vs Loan Amount in USD')

# %%
plt.style.use('seaborn')
sns.scatterplot(x = 'LoanAmount', y= 'ApplicantIncome', hue = 'Married', palette= "flare", data= data)
plt.title("Loan Amount vs ApplicantIncome in USD")
# Out:
# Text(0.5, 1.0, 'Loan Amount vs ApplicantIncome in USD')

# %%
#bar plot
sns.barplot(x = "Gender" , y ="LoanAmount", estimator = sum, data = data)

# %%
sns.barplot(x = "Gender", y= "LoanAmount" , hue= "Self_Employed", estimator = sum, data = data)
plt.title("Gender by Sum Loan Amount")
# Out:
# Text(0.5, 1.0, 'Gender by Sum Loan Amount')

# %%
import numpy
sns.barplot(x ="Gender" , y = "LoanAmount", hue= "Self_Employed", estimator = numpy.mean, data =data)
plt.title("Gender by Sum Loan Amount")
# Out:
# Text(0.5, 1.0, 'Gender by Sum Loan Amount')

# %%
#lineplot
sns.lineplot(x = "LoanAmount", y = "ApplicantIncome", hue= "Gender",  data = data)
plt.title("Loan Amount by Applicant Income")
plt.savefig("graph1.png")

# %%
sns.displot(x = "LoanAmount", color ="green" , data = data)

# %%
sns.displot(data["LoanAmount"], color ="blue" ,)

# %%
sns.distplot(data["LoanAmount"], color= "red")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data["LoanAmount"], color= "red", kde= True)
plt.title(" Loan Amount Distribution")
plt.ylabel("Freq")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Freq')

# %%
from scipy.stats import  norm
sns.distplot(data["LoanAmount"], color= "red", fit= norm, kde= True)
plt.title(" Loan Amount Distribution")
plt.ylabel("Freq")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Freq')

# %%
sns.histplot(data = data, x= "LoanAmount")

# %%
sns.histplot(data = data, x= "ApplicantIncome", kde = True, color= "red", hue ="Gender")

# %%
plt.figure(figsize=(15,6))
sns.histplot(data = data, x= "ApplicantIncome", kde = True, color= "red", hue ="Gender")

# %%
plt.figure(figsize=(15,6))
plot = sns.histplot(data = data, x= "ApplicantIncome", kde = True, color= "red", hue ="Gender")
plot.set_xticklabels(plot.get_xticklabels(), rotation =40, ha = "right")
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]

# %%
#heat maps
data.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116266    0.565886
# CoapplicantIncome        -0.116266           1.000000    0.189364
# LoanAmount                0.565886           0.189364    1.000000
# Loan_Amount_Term         -0.044361          -0.059135    0.036044
#
#                    Loan_Amount_Term
# ApplicantIncome           -0.044361
# CoapplicantIncome         -0.059135
# LoanAmount                 0.036044
# Loan_Amount_Term           1.000000

# %%
sns.heatmap(data.corr())

# %%
sns.heatmap(data.corr(), cmap ="Blues") #Reds, Blues and Greens

# %%
sns.heatmap(data.corr(), cmap ="Blues", annot = True)

# %%
# Catplot , Continous and Categorical Data
sns.catplot(x = "LoanAmount", y= "ApplicantIncome", data = data, hue = "Gender")

# %%
# Catplot , Continous and Categorical Data
sns.catplot(x = "Gender", y= "ApplicantIncome", data = data, hue = "Self_Employed", col= "Education")

# %%
# Catplot , Continous and Categorical Data
sns.catplot(x = "Gender", y= "ApplicantIncome", data = data, hue = "Self_Employed", col= "Education", kind = "strip")

# %%
# Catplot , Continous and Categorical Data
sns.catplot(x = "Gender", y= "ApplicantIncome", data = data, hue = "Self_Employed", col= "Property_Area", kind = "strip")

# %%
# Catplot , Continous and Categorical Data
sns.catplot(x = "Gender", y= "ApplicantIncome", data = data, hue = "Self_Employed", col= "Property_Area", kind = "boxen")
# kinds: swarm, strip,box, violin, boxen,point,bar,count
